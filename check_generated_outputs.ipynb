# %%
import pandas as pd

# %%
doc4 = pd.read_csv('./data/generated_outputs/doc4.csv')
doc5 = pd.read_csv('./data/generated_outputs/doc5.csv')

# %%
doc4
# Out:
#   Risk ID                                   Risk Description  Project Stage  \
# 0      R1  Opening of the Moorgate\nCross rail station is...            NaN
# 1      R2  The Riney highways contract\nis due to expire ...            NaN
# 2      R3  Delays to the four\ndevelopments surrounding\n...            NaN
# 3      R4  Infrastructure and utilities\ndifficulties at ...            NaN
# 4      R5  Key stakeholder(s) do not\nendorse design options            NaN
# 5      R6  Delays/changes to\ndependency projects, such\n...            NaN
# 6      R7  Breakdown in engagement\nwith key stakeholders...            NaN
# 7      R8  TfL restructure may mean that\nno dedicated sc...            NaN
# 8      R9  There is a potential that the\nproposed scheme...            NaN
# 9     R10  Requirement to keep the\nability for resilienc...            NaN
#
#    Project Category  Risk Owner  Mitigating Action  Likelihood (1-10)  \
# ...

# %%
doc5
# Out:
#    Risk ID                                   Risk Description  Project Stage  \
# 0        1                                Legislative changes            NaN
# 1        2                                             Brexit            NaN
# 2        3  Failure of contractors and suppliers working o...            NaN
# 3        4                              Failure of IT systems            NaN
# 4        5  Insufficient staff to provide Council services...            NaN
# 5        6      Breach of ICT security causes loss of service            NaN
# 6        7  Lack of access to Council premises prevents se...            NaN
# 7        8         Funding changes make Council unsustainable            NaN
# 8        9  The Council’s ability to cope with a natural d...            NaN
# 9       10                   Major health and safety incident            NaN
#
#    Project Category  Risk Owner  \
# 0               NaN         NaN
# 1               NaN         NaN
# ...
