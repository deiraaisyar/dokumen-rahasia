# %%
import pandas as pd

# %%
doc4 = pd.read_csv('./data/generated_outputs/doc4.csv')
doc5 = pd.read_csv('./data/generated_outputs/doc5.csv')

# %%
doc4
# Out:
#   Risk ID                                   Risk Description  \
# 0      R1  Opening of the Moorgate\nCross rail station is...
# 1      R2  The Riney highways contract\nis due to expire ...
# 2      R3  Delays to the four\ndevelopments surrounding\n...
# 3      R4  Infrastructure and utilities\ndifficulties at ...
# 4      R5  Key stakeholder(s) do not\nendorse design options
# 5      R6  Delays/changes to\ndependency projects, such\n...
# 6      R7  Breakdown in engagement\nwith key stakeholders...
# 7      R8  TfL restructure may mean that\nno dedicated sc...
# 8      R9  There is a potential that the\nproposed scheme...
# 9     R10  Requirement to keep the\nability for resilienc...
#
#                   Project Stage  Project Category              Risk Owner  \
# 0  Construction / Commissioning    Infrastructure         Project Manager
# 1              Pre-construction       Procurement    Construction Manager
# ...

# %%
doc5
# Out:
#     Risk ID                                   Risk Description Project Stage  \
# 0         1                                Legislative changes     Operation
# 1         2                                             Brexit     Operation
# 2         3  Failure of contractors and suppliers working o...     Operation
# 3         4                              Failure of IT systems    Operations
# 4         5  Insufficient staff to provide Council services...     Operation
# 5         6      Breach of ICT security causes loss of service    Operations
# 6         7  Lack of access to Council premises prevents se...     Operation
# 7         8         Funding changes make Council unsustainable    Operations
# 8         9  The Council’s ability to cope with a natural d...     Operation
# 9        10                   Major health and safety incident    Operations
# 10       11      Fraud and error committed against the Council     Operation
# ...
