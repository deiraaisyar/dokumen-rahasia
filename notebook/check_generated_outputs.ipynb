# %%
import pandas as pd

# %%
doc1 = pd.read_csv('../data/generated_outputs/doc1.csv')
doc2 = pd.read_csv('../data/generated_outputs/doc2.csv')
doc3 = pd.read_csv('../data/generated_outputs/doc3.csv')
doc4 = pd.read_csv('../data/generated_outputs/doc4.csv')
doc5 = pd.read_csv('../data/generated_outputs/doc5.csv')

# %%
doc1
# Out:
#    Date Added  Risk ID                                   Risk Description  \
# 0   21-Feb-17        1                    Data sharing from BBSRI at risk
# 1   21-Feb-17        2                   Ice data collection unsuccessful
# 2   21-Feb-17        3  Appropriate permits and licenses procured in t...
# 3   21-Feb-17        4          Wet Gap Generator design not yet complete
# 4   21-Feb-17        5  Timing of generator procurement from IKM could...
# 5   21-Feb-17        6                       components are not available
# 6   21-Feb-17        7  Fabricated components have significant lead times
# 7   21-Feb-17        8  Fabricated components have significant lead times
# 8   21-Feb-17        9  Singel source vendor for some components that ...
# 9   21-Feb-17       10   components are not available, integration of ...
# 10  21-Feb-17       11  Fabrication delays and out of spec delivered p...
# 11  21-Feb-17       12                       components are not available
# ...

# %%
doc2
# Out:
#     Date Added  Risk ID                                   Risk Description  \
# 0          NaN        3  Failure to discharge planning and listed build...
# 1          NaN        4               Planning conditions impact on budget
# 2          NaN       10  Electricity provider works delayed or non-conf...
# 3          NaN       11  Building Control Sign Off delay due to\nlack o...
# 4          NaN       12            Impact of boat companies (City Cruises)
# 5          NaN       13      Party wall negotiations & construction access
# 6          NaN       14  Failure to secure market interest for restaura...
# 7          NaN       16                       Increased construction costs
# 8          NaN       18                          Sub-contractor insolvency
# 9          NaN       20  Surveys required to determine ground\nconditio...
# 10         NaN       21                  Identification of active movement
# ...

# %%
doc3
# Out:
#    Date Added   Number                                   Risk Description  \
# 0         NaN  ICT-001  Identity and Access Management (IAM) systems c...
# 1         NaN  ICT-002  Backup and recovery services are not documente...
# 2         NaN  ICT-003  Critical Systems are supported by out of date ...
#
#             Project Stage        Project Category              Risk Owner  \
# 0  Construction Operation           Cybersecurity  Infrastructure Manager
# 1  Construction Operation             Operational  Infrastructure Manager
# 2  Construction Operation  Infrastructure Upgrade  Infrastructure Manager
#
#    Likelihood (1-10)  Impact (1-10) Risk Priority (low, med, high)  \
# 0                  3              7                           High
# 1                  9              7                            Med
# 2                 10              7                           High
#
#                                    Mitigating Action
# ...

# %%
doc4
# Out:
#   Risk ID                                   Risk Description  \
# 0      r1  opening of the moorgate cross rail station is ...
# 1      r2  the riney highways contract is due to expire i...
# 2      r3  delays to the four developments surrounding th...
# 3      r4  infrastructure and utilities difficulties at t...
# 4      r5    key stakeholder s do not endorse design options
# 5      r6  delays changes to dependency projects such as ...
# 6      r7  breakdown in engagement with key stakeholders ...
# 7      r8  tfl restructure may mean that no dedicated sch...
# 8      r9  there is a potential that the proposed scheme ...
# 9     r10  requirement to keep the ability for resilience...
#
#       Project Stage Project Category                        Risk Owner  \
# 0  Pre Construction       Dependency                   Project Manager
# 1  Pre Construction       Contractor                   Project Manager
# 2      Construction       Dependency                   Project Manager
# ...

# %%
doc5
# Out:
#     Risk ID                                   Risk Description  \
# 0         1                                legislative changes
# 1         2                                             brexit
# 2         3  failure of contractors and suppliers working o...
# 3         4                              failure of it systems
# 4         5  insufficient staff to provide council services...
# 5         6      breach of ict security causes loss of service
# 6         7  lack of access to council premises prevents se...
# 7         8         funding changes make council unsustainable
# 8         9  the council s ability to cope with a natural d...
# 9        10                   major health and safety incident
# 10       11      fraud and error committed against the council
# 11       12        failure of external investment institutions
# 12       13  failure of governance in major partners or in ...
# 13       14        failure to achieve required savings targets
# ...
