# %%
import pandas as pd

# %%
df1 = pd.read_csv('./data/preprocessed_inputs/df1.csv')
df2 = pd.read_csv('./data/preprocessed_inputs/df2.csv')
df3 = pd.read_csv('./data/preprocessed_inputs/df3.csv')
df4 = pd.read_csv('./data/preprocessed_inputs/df4.csv')
df5 = pd.read_csv('./data/preprocessed_inputs/df5.csv')

# %%
df1
# Out:
#       Budget Period Revision Date RBS Level 1                RBS Level 2  \
# 0   budget period 1    2017 02 21    external             4 6 regulatory
# 1   budget period 1    2017 02 21    external   4 9 external stakeholder
# 2   budget period 2    2017 02 21    external             4 6 regulatory
# 3   budget period 2    2017 02 21   technical             1 5 technology
# 4   budget period 2    2017 02 21  commercial  3 3 suppliers and vendors
# 5   budget period 2    2017 02 21  commercial  3 3 suppliers and vendors
# 6   budget period 2    2017 02 21  commercial  3 3 suppliers and vendors
# 7   budget period 2    2017 02 21  commercial  3 3 suppliers and vendors
# 8   budget period 2    2017 02 21  commercial  3 3 suppliers and vendors
# 9   budget period 2    2017 02 21  commercial  3 3 suppliers and vendors
# 10  budget period 2    2017 02 21  commercial  3 3 suppliers and vendors
# 11  budget period 2    2017 02 21  commercial  3 3 suppliers and vendors
# 12  budget period 2    2017 02 21  commercial  3 3 suppliers and vendors
# 13  budget period 2    2017 02 21  commercial  3 3 suppliers and vendors
# 14  budget period 2    2017 02 21  commercial  3 3 suppliers and vendors
# 15  budget period 2    2017 02 21   technical             1 5 technology
# 16  budget period 2    2017 02 21   technical             1 5 technology
# 17  budget period 2    2017 02 21   technical             1 5 technology
# 18  budget period 2    2017 02 21   technical             1 5 technology
# 19  budget period 2    2017 02 21   technical             1 5 technology
# 20  budget period 2    2017 02 21   technical             1 5 technology
# 21  budget period 2    2017 02 21   technical             1 5 technology
# 22  budget period 2    2017 02 21   technical             1 5 technology
# 23  budget period 2    2017 02 21   technical             1 5 technology
# 24  budget period 2    2017 02 21   technical             1 5 technology
# 25  budget period 3    2017 02 24    external             4 6 regulatory
# 26  budget period 3    2017 02 24  management     2 1 project management
# 27  budget period 3    2017 02 24   technical   1 6 technical interfaces
# 28  budget period 3    2017 02 24   technical     1 7 system reliability
# 29  budget period 3    2017 02 24   technical     1 7 system reliability
# 30  budget period 3    2017 02 24    external  4 4 environmental weather
# 31  budget period 3    2017 02 24   technical     1 7 system reliability
# 32  budget period 3    2017 02 24  commercial  3 3 suppliers and vendors
#
#                                             Risk Name  TRL  TPL  \
# 0   task 2 2 smolt probability of encounter model ...  7.0  7.0
# 1                           task 5 ice data collected  7.0  7.0
# 2   permitting licensing complete for in water tes...  7.0  7.0
# 3                              generator final design  7.0  7.0
# 4                               generator procurement  7.0  7.0
# 5                         buoyancy system procurement  7.0  7.0
# 6                     structural assembly procurement  7.0  7.0
# 7                                  turbine procuement  7.0  7.0
# 8                       power electronics procurement  7.0  7.0
# 9                                   scada procurement  7.0  7.0
# 10                   power and data cable procurement  7.0  7.0
# 11                          mooring sytem procurement  7.0  7.0
# 12                              dirveline procurement  7.0  7.0
# 13                       mechanical brake procurement  7.0  7.0
# 14                       mechanical brake procurement  7.0  7.0
# 15                         buoyancy system validation  7.0  7.0
# 16                     structural assembly validation  7.0  7.0
# 17                                 turbine validation  7.0  7.0
# 18                               generator validation  7.0  7.0
# 19                       power electronics validation  7.0  7.0
# 20                                   scada validation  7.0  7.0
# 21                    power and data cable validation  7.0  7.0
# 22                           mooring sytem validation  7.0  7.0
# 23                               dirveline validation  7.0  7.0
# 24                                   mechanical brake  7.0  7.0
# 25              receipt of all permits and licesenses  NaN  NaN
# 26                      component delivery to igiugig  7.0  7.0
# 27                                    device assmebly  7.0  7.0
# 28                   power system comissioning issues  7.0  7.0
# 29                      complications with winter ice  6.0  6.0
# 30                  adverse salmon smolt interactions  6.0  6.0
# 31                       device removal complications  7.0  7.0
# 32  higher cost for maintenance and logistical sup...  7.0  6.0
#
#           Technology Life Phase                        Risk Owner  \
# 0                           NaN           n johnson environmental
# 1                           NaN                 j kasper uaa lead
# 2   multiple or all life phases           n johnson environmental
# 3                        design             r tyler lead engineer
# 4    assembly and commissioning             r tyler lead engineer
# 5   multiple or all life phases             r tyler lead engineer
# 6   multiple or all life phases             r tyler lead engineer
# 7   multiple or all life phases             r tyler lead engineer
# 8   multiple or all life phases  m worthington project management
# 9   multiple or all life phases             r tyler lead engineer
# 10  multiple or all life phases  m worthington project management
# 11  multiple or all life phases             r tyler lead engineer
# 12  multiple or all life phases             r tyler lead engineer
# 13  multiple or all life phases             r tyler lead engineer
# 14  multiple or all life phases             r tyler lead engineer
# 15  multiple or all life phases             r tyler lead engineer
# 16  multiple or all life phases             r tyler lead engineer
# 17  multiple or all life phases             r tyler lead engineer
# 18  multiple or all life phases             r tyler lead engineer
# 19  multiple or all life phases  m worthington project management
# 20  multiple or all life phases             r tyler lead engineer
# 21  multiple or all life phases  m worthington project management
# 22  multiple or all life phases             r tyler lead engineer
# 23  multiple or all life phases             r tyler lead engineer
# 24  multiple or all life phases             r tyler lead engineer
# 25  multiple or all life phases           n johnson environmental
# 26               transportation  m worthington project management
# 27   assembly and commissioning             r tyler lead engineer
# 28   assembly and commissioning  m worthington project management
# 29               extreme events             r tyler lead engineer
# 30      normal power production           n johnson environmental
# 31              decommissioning  m worthington project management
# 32      normal power production  m worthington project management
#
#     Baseline +/-  ... Response Strategy  \
# 0            NaN  ...          mitigate
# 1            NaN  ...          mitigate
# 2            NaN  ...             avoid
# 3            NaN  ...          mitigate
# 4            NaN  ...             avoid
# 5            NaN  ...             avoid
# 6            NaN  ...          mitigate
# 7            NaN  ...          mitigate
# 8            NaN  ...          mitigate
# 9            NaN  ...             avoid
# 10           NaN  ...          mitigate
# 11           NaN  ...             avoid
# 12           NaN  ...          mitigate
# 13           NaN  ...          mitigate
# 14           NaN  ...          mitigate
# 15           NaN  ...             avoid
# 16           NaN  ...             avoid
# 17           NaN  ...             avoid
# 18           NaN  ...             avoid
# 19           NaN  ...             avoid
# 20           NaN  ...             avoid
# 21           NaN  ...             avoid
# 22           NaN  ...             avoid
# 23           NaN  ...             avoid
# 24           NaN  ...             avoid
# 25           NaN  ...             avoid
# 26           NaN  ...          mitigate
# 27           NaN  ...          mitigate
# 28           NaN  ...          mitigate
# 29           NaN  ...          mitigate
# 30           NaN  ...          mitigate
# 31           NaN  ...          mitigate
# 32           NaN  ...          mitigate
#
#                                  Response Description  \
# 0   facilitate conversations with umaine on data s...
# 1               real time data collection implemented
# 2   ferc final license application submittal scheu...
# 3     design reviews and component validation testing
# 4   ensure generator delivery by 2 2018 to allow a...
# 5   compile bom and ascertain component lead times...
# 6   frequent vendor communication issue po with ro...
# 7   frequent vendor communication issue po with ro...
# 8   frequent vendor communication issue po with ro...
# 9   compile bom and ascertain component lead times...
# 10  compile bom and ascertain component lead times...
# 11  compile bom and ascertain component lead times...
# 12  frequent vendor communication issue po with ro...
# 13  frequent vendor communication issue po with ro...
# 14  frequent vendor communication issue po with ro...
# 15  utilizing incremetnal improvements to a proven...
# 16  fea analysis of structure include load factors...
# 17  utilize cfd as design tool for performance val...
# 18  factory accpetance testing and laboratory test...
# 19  factory accpetance tests and sequenced laborat...
# 20  factory accpetance tests and sequenced laborat...
# 21  utilize proven cable technology utilize second...
# 22  design to dnv standards utilize geophyisical k...
# 23  throught validation testing desing system for ...
# 24  throught validation testing redundant electric...
# 25  continue regular dialogue with regulatory agen...
# 26  track project schedule align component validat...
# 27  device assembly is fdifficult or requires work...
# 28  prior device testing and component testing in ...
# 29  collection of in river ice data for 2 years pr...
# 30  develop rigorous fish monitroing pland in budg...
# 31  buoyancy system includes redundant and isoalte...
# 32  developing system requirements will be critica...
#
#                       Response Timing  Residual SEV Residual FRQ Residual RPN  \
# 0                                 now           1.0          3.0          3.0
# 1                                 now           2.0          1.0          2.0
# 2                                 now           4.0          3.0         12.0
# 3             before design finalized           3.0          2.0          NaN
# 4                before manufacturing           3.0          3.0          9.0
# 5                    before po issued           3.0          1.0          3.0
# 6                    before po issued           3.0          2.0          6.0
# 7                    before po issued           3.0          2.0          6.0
# 8                                 now           3.0          3.0          9.0
# 9                    before po issued           3.0          3.0          9.0
# 10                   before po issued           3.0          3.0          NaN
# 11                   before po issued           3.0          1.0          3.0
# 12                   before po issued           3.0          2.0          6.0
# 13                   before po issued           3.0          2.0          6.0
# 14                   before po issued           3.0          2.0          6.0
# 15  before assembly and commissioning           3.0          2.0          6.0
# 16  before assembly and commissioning           3.0          2.0          6.0
# 17  before assembly and commissioning           3.0          2.0          6.0
# 18  before assembly and commissioning           3.0          2.0          6.0
# 19  before assembly and commissioning           3.0          3.0          9.0
# 20  before assembly and commissioning           3.0          3.0          9.0
# 21  before assembly and commissioning           4.0          2.0          8.0
# 22  before assembly and commissioning           5.0          2.0         10.0
# 23  before assembly and commissioning           4.0          3.0         12.0
# 24  before assembly and commissioning           3.0          3.0          9.0
# 25                           december           5.0          3.0         15.0
# 26  before assembly and commissioning           4.0          2.0          8.0
# 27                               june           4.0          2.0          8.0
# 28                             august           5.0          2.0         10.0
# 29                               june           5.0          3.0         15.0
# 30                                may           4.0          3.0         12.0
# 31                                may           5.0          2.0         10.0
# 32  before assembly and commissioning           2.0          2.0          4.0
#
#                                  Residual Description  \
# 0   if data is not shared move on to next step of ...
# 1   if real time data collection is not successful...
# 2                    ferc license not granted in time
# 3   manufactured product is stil out of specificaiton
# 4   generator has manufacturing or integration iss...
# 5                       unexepcted component shortage
# 6                       unexpected fabrication delays
# 7                       unexpected fabrication delays
# 8            unexpected design fabrication fat delays
# 9   unexepcted component shortage personel shortag...
# 10                      unexepcted component shortage
# 11                      unexepcted component shortage
# 12                      unexpected fabrication delays
# 13                      unexpected fabrication delays
# 14                      unexpected fabrication delays
# 15  unexpected component failure after validation ...
# 16                       unexpcted structural failure
# 17                         unexpected turbine failure
# 18                       unexpected generator failure
# 19  unexpected power electonics failure or grid in...
# 20  unexpected scada failure or communciations issues
# 21            unexpected power and data cable failure
# 22                  unexpected mooring system failure
# 23                       unexpected direvline failure
# 24                unexpected mechanical brake failure
# 25  uncertainity with regurlatory agency approvals...
# 26  unexcepcted or uncontrollabel circumstances le...
# 27  preassembl as many components as possible prio...
# 28  per shipment validation work in nikiksi with d...
# 29  uncertiainty of ice interaction or in river fo...
# 30  lack of established industry standard for smol...
# 31  redundant pretested systems reduce likleihood ...
# 32                higher cost risk should be lessened
#
#                                       Secondary Risks  \
# 0                                                 NaN
# 1                                increased complexity
# 2                          schedule slip budget creep
# 3                        increased cost schedule slip
# 4                           increased effort and cost
# 5                                                 NaN
# 6                           increased cost and effort
# 7                           increased cost and effort
# 8                           increased cost and effort
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                          increased cost and effort
# 13                          increased cost and effort
# 14                          increased cost and effort
# 15                          increased cost and effort
# 16  additional desing work materials or strucutral...
# 17  increased cost added structural elements could...
# 18              increased cost schedule slip possible
# 19               incresed cost schedule slip possible
# 20                                     increased cost
# 21  increased cost and operational complexity incr...
# 22  increased size and operational complexity as a...
# 23                                      incresed cost
# 24                       incresed cost and complexity
# 25                          increased cost and effort
# 26                          increased cost and effort
# 27                          increased cost and effort
# 28  testing may cause damge to components increase...
# 29                          increased cost and effort
# 30  incresed cost without eliminating or adequtely...
# 31  increased cost and effort increase system comp...
# 32  complex supply chain and remote area logistics...
#
#                        Recommendations & Action Items  \
# 0   n johnson to continue to faciliate conversatio...
# 1   uaf to take lead on techical side m worthingto...
# 2   initiate communication with regulatory agencie...
# 3   work closeley with generator vendor to develop...
# 4   continue communication with ikm and orpc irela...
# 5                                 use cots components
# 6   freqent vendor communications contract include...
# 7   freqent vendor communications contract include...
# 8   freqent vendor communications contract include...
# 9   use cots components start acada development early
# 10                 use cots components where possible
# 11                                use cots components
# 12  freqent vendor communications contract include...
# 13  freqent vendor communications contract include...
# 14  freqent vendor communications contract include...
# 15  clearly scope validation tests to ensure tests...
# 16  complete thorough design and analysis desing t...
# 17  thorough design and analysis utilizing third p...
# 18  ensure adequate factory acceptance testing and...
# 19  adequate factory acceptance tests thorough lab...
# 20  adequate bench tests through full length power...
# 21  ensure cable meets specs test full length cabl...
# 22  utilize industry expertise to guide mooring sy...
# 23  complete thorough validation testing and incor...
# 24  complete thorough validation testing including...
# 25  manage personnel time and availablity accordingly
# 26                        track shipment continuously
# 27  include device assembly in validation with as ...
# 28  test all components in configuration for igiug...
# 29  perform thorough analysis of ice data from in ...
# 30  establish adaptive management plan with agenci...
# 31  document results of pre testing in nikiksi vis...
# 32  structure contract to include incentives penal...
#
#                                      Contingency Plan
# 0   continue environmental monitoring plan develop...
# 1   redesign ice study equipment for oper water te...
# 2   consider operating under verdant exemption for...
# 3              refurbish and reuse exisitng generator
# 4              refurbish and reuse exisitng generator
# 5              delay buoyancy system validation tests
# 6                  delay full system validation tests
# 7                  delay full system validation tests
# 8                         delay laboratory validation
# 9                 delay scada system validation tests
# 10        delay power and data cable validation tests
# 11              delay moorins system validation tests
# 12                 delay full system validation tests
# 13            delay mechanical brake validation tests
# 14            delay mechanical brake validation tests
# 15  secondary redundant isolated recovery system a...
# 16  utilize local resources to effect repair and o...
# 17  accept lower power output system removal inspe...
# 18  refurbish and reuse protptype generator while ...
# 19  dissipate power through secondary load bank or...
# 20  operate with simplified control system remove ...
# 21                       replace power and data cable
# 22  allow anchor slip as favorable failure mode re...
# 23  validation tests in advance of system build le...
# 24  use electrical brake or remove system from cur...
# 25  move forward under verdant exemption secure ne...
# 26  delay deployment to 2019 if component delivery...
# 27  perfrom redesign and modifcation work in igiug...
# 28  resolove issues with locally available resourc...
# 29  remove divce from irver if possible or curtail...
# 30  stop device operations during smolt outmigrati...
# 31  utilize locaaly available resources to develop...
# 32  follow contractual provisions for higher costs...
#
# [33 rows x 25 columns]

# %%
df2
# Out:
#     Risk ID                                   Risk Description  \
# 0         3  failure to discharge planning and listed build...
# 1         4               planning conditions impact on budget
# 2        10  electricity provider works delayed or non conf...
# 3        11  building control sign off delay due to lack of...
# 4        12              impact of boat companies city cruises
# 5        13        party wall negotiations construction access
# 6        14  failure to secure market interest for restaura...
# 7        16                       increased construction costs
# 8        18                          sub contractor insolvency
# 9        20  surveys required to determine ground condition...
# 10       21                  identification of active movement
# 11       22                           unidentified archaeology
# 12       23                        additional surveys required
# 13       26      unrealistic programme submitted by contractor
# 14       27  programme delays due to flood levels impacting...
# 15       29                          delay to design programme
# 16       31  underpinning piling and crack repairs to be co...
# 17       32                    discovering structural unknowns
# 18       35  undetected services not identified on surveys ...
# 19       40  river source heat pump license approval by the...
# 20       41               sourcing stone for remediation works
# 21       42  structural damage and the repairs required to ...
# 22       48           outstanding defects remaining unresolved
# 23       50  costs exceeds allocated budget non constructio...
# 24       51  incorrect estimation design errors and ambigui...
# 25       56        availability of specialist labour equipment
# 26       61  poor co ordination with design team interfaces...
# 27       62                                    rights of light
# 28       64    poor contractor performance during construction
# 29       66                     unknown south range structures
# 30       67  insufficient design detail from specialist cdp...
# 31       70                         satisfying ea requirements
# 32       72  delay in design programme due to tenant operat...
# 33       73  design changes including client changes variat...
# 34       75                                     weather delays
# 35       76        underpinning crack repairs by third parties
# 36       77  ground conditions borehole survey depth insuff...
# 37       80  instability to boundary wall following demolition
# 38       81  clashes between the existing building foundati...
# 39       82  potential drainage clash with proposed lift sh...
# 40       83           billing omissions or inaccuracies in boq
# 41       84  additional works not covered by contract docum...
# 42       85  ongoing movement in the south range given the ...
# 43       87  design change due to level of development and ...
# 44       88             council chamber cooling to be approved
#
#                                                Impact  \
# 0                                                 NaN
# 1                             increase project budget
# 2   works to provide new supply are delayed not in...
# 3   revisit design to address concerns of building...
# 4             impact delivery site servicing strategy
# 5   objection from neighbours potential delay to p...
# 6   restaurant not achieving appropriate tenant an...
# 7   exchange rate on materials impact of internati...
# 8                             impacts main contractor
# 9   possible need to re visit design deal with con...
# 10       proven to be active remediation impacts cost
# 11            further evaluation required cost impact
# 12                                        cost impact
# 13                                                NaN
# 14         works stop cost and programme implications
# 15            client contractor impact cost programme
# 16  may resolve existing cracks and movement of th...
# 17  costs of additional surveys and remediation works
# 18  programme re design cost impact to address unk...
# 19                       delay in no approval from ea
# 20  quarry that stone exists from is closed impact...
# 21  finding the right solution to undertake the un...
# 22  cyc left with legacy issues and building defec...
# 23  particular risks surrounding consultant fees f...
# 24                          construction cost overrun
# 25  change in specification need to appoint specia...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  risk of discovering old basement causing issue...
# 30  impacts the sign off planning conditions liste...
# 31  incident occurring which stops the work and ac...
# 32       operator changes impacting on cost programme
# 33                          construction cost overrun
# 34                  delay to programme wind temp rain
# 35      cracks may appear elsewhere remediation costs
# 36  proposed piling designs impacted by this and r...
# 37                    structural works required piers
# 38  co ordination of drainage with foundations dur...
# 39               additional external drainage network
# 40  missing information within the boq resulting i...
# 41                                     cost programme
# 42  underpinning works reinstated resulting in cos...
# 43  impact on cost and programme changes may delay...
# 44          revisit of design proposals time and cost
#
#                  Project Stage     Risk Category  Likelihood (1-10)  \
# 0             pre construction          planning           3.333333
# 1             pre construction          planning           6.666667
# 2                 construction       legislation           3.333333
# 3   construction commissioning       legislation           3.333333
# 4                 construction          planning           3.333333
# 5             pre construction          planning           5.000000
# 6   pre construction operation       procurement           5.000000
# 7                 construction       procurement           5.000000
# 8                 construction       procurement           6.666667
# 9             pre construction           surveys           1.666667
# 10            pre construction           surveys           1.666667
# 11            pre construction           surveys           3.333333
# 12            pre construction           surveys           1.666667
# 13            pre construction         programme           1.666667
# 14                construction         programme          10.000000
# 15            pre construction            design           5.000000
# 16            pre construction            design           5.000000
# 17                construction            design           8.333333
# 18                construction          services           3.333333
# 19            pre construction          services           1.666667
# 20                construction         materials           6.666667
# 21                construction      construction           6.666667
# 22               commissioning     post contract           3.333333
# 23  construction commissioning         financial           8.333333
# 24            pre construction         financial           5.000000
# 25                construction      construction           5.000000
# 26                construction            design           3.333333
# 27            pre construction  adjoining owners           1.666667
# 28                construction      construction           3.333333
# 29                construction            design           6.666667
# 30            pre construction            design           5.000000
# 31            pre construction            design           1.666667
# 32            pre construction            design           5.000000
# 33                construction         financial          10.000000
# 34                construction      construction           8.333333
# 35                construction            design           3.333333
# 36            pre construction           surveys           5.000000
# 37                construction            design           5.000000
# 38                construction           surveys           5.000000
# 39                construction           surveys           1.666667
# 40            pre construction         financial           6.666667
# 41                construction         financial          10.000000
# 42      construction operation            design           3.333333
# 43            pre construction            design           3.333333
# 44               commissioning            design           3.333333
#
#     Impact (1-10)  Risk Index                        Risk Owner  \
# 0        1.666667         2.0                   project manager
# 1        5.000000        14.0                   project manager
# 2        3.333333         4.0                   project manager
# 3        3.333333         4.0                   project manager
# 4        1.666667         2.0                   project manager
# 5        6.666667        10.5                   project manager
# 6        8.333333        15.0                   project manager
# 7        5.000000         9.0                   project manager
# 8        5.000000        12.0              construction manager
# 9        8.333333         3.0                     lead engineer
# 10       8.333333         5.0               structural engineer
# 11       3.333333         4.0                  environment lead
# 12       1.666667         1.0                   project manager
# 13       5.000000         2.5                   project manager
# 14       8.333333        24.0  project manager environment lead
# 15       5.000000         9.0                    design manager
# 16       8.333333        15.0               structural engineer
# 17       6.666667        17.5               structural engineer
# 18       5.000000         6.0                     lead engineer
# 19       6.666667         4.5                  environment lead
# 20       5.000000        12.0               procurement manager
# 21       6.666667        14.0               structural engineer
# 22       5.000000         4.0                   project manager
# 23       5.000000        15.0                   project manager
# 24       5.000000         9.0                    design manager
# 25       5.000000         9.0                   project manager
# 26       5.000000         6.0                    design manager
# 27       6.666667         2.5                   project manager
# 28       8.333333         9.0                   project manager
# 29       5.000000        12.0               structural engineer
# 30       1.666667         6.0                    design manager
# 31       8.333333         4.5                  environment lead
# 32       5.000000         9.0                    design manager
# 33       8.333333        30.0                   project manager
# 34       5.000000        12.5                   project manager
# 35       8.333333        10.0               structural engineer
# 36       5.000000         9.0                     lead engineer
# 37       3.333333         6.0               structural engineer
# 38       3.333333         7.5                     lead engineer
# 39       5.000000         3.0                     lead engineer
# 40       8.333333        18.0                   project manager
# 41       8.333333        27.0                   project manager
# 42       6.666667         8.0               structural engineer
# 43       3.333333         5.0                    design manager
# 44       5.000000         6.0                    design manager
#
#                                            Mitigation
# 0   design team and contractor to collate initial ...
# 1   extent of conditions known and to be reviewed ...
# 2   orders for the electrical services have been p...
# 3   continue liaison with the building control off...
# 4                       legal agreements are in place
# 5   appoint party wall surveyor and progress discu...
# 6   early engagement of agent for potential lettin...
# 7   tender prices received and under review risk s...
# 8   contractor financial checks and vetting of sub...
# 9   gi survey undertaken information obtained cont...
# 10  ongoing monitoring by arup and monitoring spec...
# 11                      evaluation of site undertaken
# 12                      undertake outstanding surveys
# 13                                      market tested
# 14  review historic flood data and issue to contra...
# 15  implementation of irs schedules design deliver...
# 16      detailed dilapidations surveys crack monitors
# 17  undertake surveys early to determine unknowns ...
# 18  utilities surveys maps obtained and plotted on...
# 19  provisional consent obtained continued dialogu...
# 20  investigate other quarries which supply the st...
# 21  bullivants arup design and vinci temporary wor...
# 22  ability to resolve within the building contrac...
# 23  review non construction costs prior to contrac...
# 24                risk sits with cyc except cdp items
# 25         dialogue with main contractor supply chain
# 26  cdp requirements have reduced from initial int...
# 27          title report does not identify any issues
# 28  contract to be signed to protect client perfor...
# 29                                                NaN
# 30    regular design reviews and interface management
# 31  waste management and compliance with the ea to...
# 32  recovery of cost time included within the agre...
# 33  traditional contract risk with cyc secure adeq...
# 34  contractor to provide impact and allowances vi...
# 35      detailed dilapidations surveys crack monitors
# 36  additional bore hole surveys indertaken no fou...
# 37  assessment of wall structure required scope of...
# 38  trial holes could be undertaken to better unde...
# 39  trial hole dug in the location and appears to ...
# 40            t t have carried out reviews of the boq
# 41  detailed change management process to be followed
# 42                            monitoring during works
# 43  coordination to be managed by design team as a...
# 44  design team to coordinate with planning conser...

# %%
df3
# Out:
#     Number                                   Risk Description  Probability  \
# 0  ict 001  identity and access management iam systems com...            3
# 1  ict 002  backup and recovery services are not documente...            9
# 2  ict 003  critical systems are supported by out of date ...           10
#
#    Severity Score              Risk Owner  \
# 0         7  high                     NaN
# 1         7   med  infrastructure manager
# 2         7  high  infrastructure manager
#
#                                          Action Plan
# 0  implement automated iam systems and multiform ...
# 1  implement automated iam systems and multiform ...
# 2  document and test backup and recovery services...

# %%
df4
# Out:
#   Risk ID                                   Risk Description  \
# 0      r1  opening of the moorgate cross rail station is ...
# 1      r2  the riney highways contract is due to expire i...
# 2      r3  delays to the four developments surrounding th...
# 3      r4  infrastructure and utilities difficulties at t...
# 4      r5    key stakeholder s do not endorse design options
# 5      r6  delays changes to dependency projects such as ...
# 6      r7  breakdown in engagement with key stakeholders ...
# 7      r8  tfl restructure may mean that no dedicated sch...
# 8      r9  there is a potential that the proposed scheme ...
# 9     r10  requirement to keep the ability for resilience...
#
#   Likelihood (1-10) Impact (1-10) Risk Priority (low, med, high)  \
# 0          possible         minor                            low
# 1          unlikely         minor                            low
# 2          possible       serious                            med
# 3          possible         major                            med
# 4          possible       serious                            med
# 5          possible       serious                            med
# 6          unlikely       serious                            low
# 7            likely         major                           high
# 8              rare       serious                            low
# 9          possible       serious                            med
#
#                                    Mitigating Action
# 0  regular engagement with crossrail from now to ...
# 1  discussions to take place internally should th...
# 2  regular engagement with developers from now un...
# 3  set expectations at the earliest stage possibl...
# 4  ensure that stakeholder working group is suitably
# 5  work with internal stakeholders to minimize an...
# 6  ensure coherent communications with stakeholde...
# 7  officers will seek to establish resources as e...
# 8  meetings with representative groups will be co...
# 9  seek to ensure that an appropriate level of re...

# %%
df5
# Out:
#     Reference                                               Risk  \
# 0           1                                legislative changes
# 1           2                                             brexit
# 2           3  failure of contractors and suppliers working o...
# 3           4                              failure of it systems
# 4           5  insufficient staff to provide council services...
# 5           6      breach of ict security causes loss of service
# 6           7  lack of access to council premises prevents se...
# 7           8         funding changes make council unsustainable
# 8           9  the council s ability to cope with a natural d...
# 9          10                   major health and safety incident
# 10         11      fraud and error committed against the council
# 11         12        failure of external investment institutions
# 12         13  failure of governance in major partners or in ...
# 13         14        failure to achieve required savings targets
# 14         15  over run of major council projects in time or ...
# 15         16  service provision affected by organisational c...
# 16         17           political changes in national priorities
# 17         18                   capital funding strategy failure
# 18         19              poor communications with stakeholders
# 19         20  commercial uncertainties associated with decis...
#
#                                               Effects  \
# 0   changes arising from central government or eu ...
# 1   uncertainty during transition period followed ...
# 2   failure of contractor or partners to deliver s...
# 3   failure to secure and manage data leads to los...
# 4   constraints to effective workforce planning le...
# 5   major it physical hardware failure or electron...
# 6                     disruption of service provision
# 7   economic changes imposed savings requirements ...
# 8   natural disaster malicious or accidental incid...
# 9   major health safety incident at council leads ...
# 10  potential for fraud corruption malpractice or ...
# 11  failure of external investment institutions af...
# 12  partnership governance not adopted or followed...
# 13  failure to achieve efficiency saving maximise ...
# 14  failure to manage projects effectively leads t...
# 15  service provision and performance affected by ...
# 16  changes in national political priorities may r...
# 17  financial risks of capital funding shortfalls ...
# 18  poor communication with stakeholders and staff...
# 19  reputational damage financial loss impact on s...
#
#     Risk_if_No_Action_Impact  Risk_if_No_Action_Likelihood  \
# 0                          5                             5
# 1                          5                             5
# 2                          4                             4
# 3                          5                             5
# 4                          4                             5
# 5                          5                             5
# 6                          5                             5
# 7                          5                             5
# 8                          5                             4
# 9                          4                             4
# 10                         5                             4
# 11                         5                             4
# 12                         4                             5
# 13                         4                             5
# 14                         4                             5
# 15                         4                             5
# 16                         5                             4
# 17                         5                             4
# 18                         4                             5
# 19                         5                             4
#
#     Risk_if_No_Action_Score  \
# 0                        25
# 1                        25
# 2                        16
# 3                        25
# 4                        20
# 5                        25
# 6                        25
# 7                        25
# 8                        20
# 9                        16
# 10                       20
# 11                       20
# 12                       20
# 13                       20
# 14                       20
# 15                       20
# 16                       20
# 17                       20
# 18                       20
# 19                       20
#
#                                            Mitigation  Current_Risk_Impact  \
# 0   monitoring officer horizon scanning by legal c...                    2
# 1   horizon scanning by legal services cmt heads o...                    2
# 2   procurement processes including financial aspe...                    3
# 3   data protection policy and procedure freedom o...                    4
# 4   learning development framework training workin...                    2
# 5   anti virus software geographically distributed...                    4
# 6   alarm and security systems fire drills busines...                    2
# 7   s151 chief finance officer financial regulatio...                    3
# 8   emergency plan emergency planning exercises be...                    4
# 9   health safety h s panel h s procedures address...                    4
# 10  anti fraud corruption policy strategy financia...                    3
# 11  policy for maximum investment borrowing levels...                    2
# 12  fsp fenland public service board cabinet and o...                    3
# 13  heightened analysis of budgets and services by...                    3
# 14  project management methodology contract standi...                    3
# 15  working environment org culture staff committe...                    3
# 16  financial workforce planning monitoring by cmt...                    3
# 17  asset mgt plan asset disposal linked to capita...                    3
# 18  internal and external regular publications sta...                    3
# 19  robust oversight and governance arrangements e...                    3
#
#     Current_Risk_Likelihood  Current_Risk_Score                    Risk_Owner  \
# 0                         5                  10                  carol pilson
# 1                         3                   6  peter catchpole carol pilson
# 2                         4                  12                           cmt
# 3                         3                  12  carol pilson peter catchpole
# 4                         3                   6                           cmt
# 5                         3                  12               peter catchpole
# 6                         3                   6               peter catchpole
# 7                         3                   9               peter catchpole
# 8                         4                  16                           cmt
# 9                         3                  12                           cmt
# 10                        3                   9  peter catchpole carol pilson
# 11                        4                   8               peter catchpole
# 12                        3                   9  carol pilson peter catchpole
# 13                        3                   9                           cmt
# 14                        2                   6                           cmt
# 15                        4                  12               peter catchpole
# 16                        4                  12                     paul medd
# 17                        3                   9               peter catchpole
# 18                        3                   9                  carol pilson
# 19                        3                   9                           cmt
#
#                                   Actions_Being_Taken  \
# 0   use intelligence to officers identify impendin...
# 1   understanding and government acting on passed ...
# 2   regular monitoring the leisure of contracts an...
# 3   effective auditing of gdpr systems and data he...
# 4   ensure all services all services have effectiv...
# 5   effective auditing of the council systems and ...
# 6   regularly test emergency emergency plan testin...
# 7   using intelligence to we are model and plan fo...
# 8   regularly test key senior emergency plan brief...
# 9   ensure health and a thorough safety is standar...
# 10  increase staff the council vigilance national ...
# 11  effective treasury the council s management re...
# 12  the annual assurance that to corporate governa...
# 13  robust control of delivery corporate including...
# 14  robust project effective management priority e...
# 15  business continuity plans plans for each servi...
# 16  understanding and the risks acting on result i...
# 17  forward planning the council s and horizon reg...
# 18  cse action plan the council s year by staff su...
# 19  all governance the council s requirements have...
#
#                                 Comments_and_Progress
# 0   continue to horizon scan for legislative and t...
# 1   withdrawal agreement bill has been lessening t...
# 2   service was outsourced in december included wi...
# 3   is live see risk 1 internet feed to fenland ha...
# 4   have published service plans learning and work...
# 5   has subscribed to the national cyber centre s ...
# 6   plans ongoing programme of review and training...
# 7   closely watching local government finance coun...
# 8   staff attend regular multi agency and planning...
# 9   health and safety regime at the ensures that t...
# 10  has assisted with each annual fraud initiative...
# 11  treasury management position is reviewed and i...
# 12  governance statement being reported governance...
# 13  of council efficiency targets continue deliver...
# 14  project management remains a council projects ...
# 15  regularly checked and tested have reviewed the...
# 16  of legislative change remain high as a of the ...
# 17  capital funding programme is reviewed by offic...
# 18  cse performance is assessed each an external e...
# 19  risk appetite is currently being risk will be ...
